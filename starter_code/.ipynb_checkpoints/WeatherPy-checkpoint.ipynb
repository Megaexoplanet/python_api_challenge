# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as rq
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_api_key
# Out:
# '375b06c2bfa9b62cd34eb840f954c3ad'

# %%
#api.openweathermap.org/data/2.5/weather?q=London&APPID=375b06c2bfa9b62cd34eb840f954c3ad

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q="

print("Beginning Data Retrival")
print("-------------------------")

record_count=1
set_count=1
weather_by_city = {}
for i, city in enumerate(cities):
    if(i%50==0 and i>=50):
        record_count=0
        set_count=set_count+1

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count = record_count+1
    try:
        city_url=url+city
        city_weather = rq.get(city_url).json()
        weather_by_city[city] = city_weather
    except:
        pass
# Out:
# Beginning Data Retrival
# -------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | iberia
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | isangel
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | nome
# Processing Record 10 of Set 1 | teguise
# Processing Record 11 of Set 1 | tazmalt
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | umm lajj
# Processing Record 14 of Set 1 | kaka
# Processing Record 15 of Set 1 | manono
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | bilma
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | illoqqortoormiut
# Processing Record 21 of Set 1 | rorvik
# Processing Record 22 of Set 1 | sao felix do xingu
# Processing Record 23 of Set 1 | mwaya
# Processing Record 24 of Set 1 | quatre cocos
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | jaicos
# Processing Record 28 of Set 1 | bam
# Processing Record 29 of Set 1 | cidreira
# Processing Record 30 of Set 1 | nanortalik
# Processing Record 31 of Set 1 | west bay
# Processing Record 32 of Set 1 | lata
# Processing Record 33 of Set 1 | salem
# Processing Record 34 of Set 1 | panaba
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | te anau
# Processing Record 37 of Set 1 | ahuimanu
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | mandera
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | shuyskoye
# Processing Record 43 of Set 1 | port lincoln
# Processing Record 44 of Set 1 | fort nelson
# Processing Record 45 of Set 1 | hami
# Processing Record 46 of Set 1 | betsiamites
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | walvis bay
# Processing Record 0 of Set 2 | broome
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | mehamn
# Processing Record 3 of Set 2 | ouango
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | barentsburg
# Processing Record 7 of Set 2 | san patricio
# Processing Record 8 of Set 2 | malaya purga
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | owando
# Processing Record 12 of Set 2 | mys shmidta
# Processing Record 13 of Set 2 | puerto escondido
# Processing Record 14 of Set 2 | anadyr
# Processing Record 15 of Set 2 | borova
# Processing Record 16 of Set 2 | gananoque
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | taolanaro
# Processing Record 20 of Set 2 | tawau
# Processing Record 21 of Set 2 | kailua
# Processing Record 22 of Set 2 | san vicente
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | eureka
# Processing Record 27 of Set 2 | menongue
# Processing Record 28 of Set 2 | maryborough
# Processing Record 29 of Set 2 | meulaboh
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | trincomalee
# Processing Record 32 of Set 2 | brandon
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | bambanglipuro
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | lupiro
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | ahipara
# Processing Record 40 of Set 2 | goderich
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | attawapiskat
# Processing Record 45 of Set 2 | pringsewu
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | zakharovo
# Processing Record 48 of Set 2 | san estanislao
# Processing Record 49 of Set 2 | bonthe
# Processing Record 0 of Set 3 | cap malheureux
# Processing Record 1 of Set 3 | geraldton
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | killybegs
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | grand river south east
# Processing Record 8 of Set 3 | ilulissat
# Processing Record 9 of Set 3 | urubicha
# Processing Record 10 of Set 3 | pisco
# Processing Record 11 of Set 3 | saint anthony
# Processing Record 12 of Set 3 | santa rosa
# Processing Record 13 of Set 3 | alice springs
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | atikokan
# Processing Record 16 of Set 3 | viedma
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | maniitsoq
# Processing Record 24 of Set 3 | paamiut
# Processing Record 25 of Set 3 | seoul
# Processing Record 26 of Set 3 | lavrentiya
# Processing Record 27 of Set 3 | malanje
# Processing Record 28 of Set 3 | tual
# Processing Record 29 of Set 3 | belushya guba
# Processing Record 30 of Set 3 | naryan-mar
# Processing Record 31 of Set 3 | labutta
# Processing Record 32 of Set 3 | burica
# Processing Record 33 of Set 3 | rincon
# Processing Record 34 of Set 3 | alamogordo
# Processing Record 35 of Set 3 | sayyan
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | murgab
# Processing Record 38 of Set 3 | padang
# Processing Record 39 of Set 3 | nokia
# Processing Record 40 of Set 3 | longyearbyen
# Processing Record 41 of Set 3 | lompoc
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | kutum
# Processing Record 45 of Set 3 | acton
# Processing Record 46 of Set 3 | kudahuvadhoo
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | bristol
# Processing Record 49 of Set 3 | dwarka
# Processing Record 0 of Set 4 | torbay
# Processing Record 1 of Set 4 | tiznit
# Processing Record 2 of Set 4 | bluff
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | qiqihar
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | semikarakorsk
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | ialibu
# Processing Record 10 of Set 4 | kalevala
# Processing Record 11 of Set 4 | chicama
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | vaini
# Processing Record 14 of Set 4 | derbent
# Processing Record 15 of Set 4 | nanakuli
# Processing Record 16 of Set 4 | mus
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | khani
# Processing Record 19 of Set 4 | timbiqui
# Processing Record 20 of Set 4 | grindavik
# Processing Record 21 of Set 4 | stornoway
# Processing Record 22 of Set 4 | korla
# Processing Record 23 of Set 4 | vila franca do campo
# Processing Record 24 of Set 4 | fare
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | chichester
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | kruisfontein
# Processing Record 29 of Set 4 | magugu
# Processing Record 30 of Set 4 | nhamunda
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | araouane
# Processing Record 34 of Set 4 | chalus
# Processing Record 35 of Set 4 | manacapuru
# Processing Record 36 of Set 4 | ngunguru
# Processing Record 37 of Set 4 | kalmunai
# Processing Record 38 of Set 4 | ucluelet
# Processing Record 39 of Set 4 | osa
# Processing Record 40 of Set 4 | bellevue
# Processing Record 41 of Set 4 | canandaigua
# Processing Record 42 of Set 4 | yovon
# Processing Record 43 of Set 4 | flateby
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | kidal
# Processing Record 46 of Set 4 | houma
# Processing Record 47 of Set 4 | bilibino
# Processing Record 48 of Set 4 | qasigiannguit
# Processing Record 49 of Set 4 | khatanga
# Processing Record 0 of Set 5 | codrington
# Processing Record 1 of Set 5 | husavik
# Processing Record 2 of Set 5 | tasiilaq
# Processing Record 3 of Set 5 | hofn
# Processing Record 4 of Set 5 | saleaula
# Processing Record 5 of Set 5 | sabha
# Processing Record 6 of Set 5 | sri aman
# Processing Record 7 of Set 5 | diffa
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | victoria
# Processing Record 10 of Set 5 | okhotsk
# Processing Record 11 of Set 5 | borzya
# Processing Record 12 of Set 5 | el balyana
# Processing Record 13 of Set 5 | oktyabrskiy
# Processing Record 14 of Set 5 | cocorit
# Processing Record 15 of Set 5 | marsabit
# Processing Record 16 of Set 5 | yarim
# Processing Record 17 of Set 5 | pedernales
# Processing Record 18 of Set 5 | catuday
# Processing Record 19 of Set 5 | allapalli
# Processing Record 20 of Set 5 | muncar
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | maxixe
# Processing Record 23 of Set 5 | hithadhoo
# Processing Record 24 of Set 5 | nhulunbuy
# Processing Record 25 of Set 5 | sakaiminato
# Processing Record 26 of Set 5 | sitka
# Processing Record 27 of Set 5 | cabedelo
# Processing Record 28 of Set 5 | luganville
# Processing Record 29 of Set 5 | tarakan
# Processing Record 30 of Set 5 | dandong
# Processing Record 31 of Set 5 | naifaru
# Processing Record 32 of Set 5 | tianpeng
# Processing Record 33 of Set 5 | semey
# Processing Record 34 of Set 5 | krasyliv
# Processing Record 35 of Set 5 | oistins
# Processing Record 36 of Set 5 | kismayo
# Processing Record 37 of Set 5 | puerto ayacucho
# Processing Record 38 of Set 5 | norrkoping
# Processing Record 39 of Set 5 | aklavik
# Processing Record 40 of Set 5 | san quintin
# Processing Record 41 of Set 5 | bahia blanca
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | hamilton
# Processing Record 44 of Set 5 | valer
# Processing Record 45 of Set 5 | kahta
# Processing Record 46 of Set 5 | santa ana
# Processing Record 47 of Set 5 | saint-augustin
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | buta
# Processing Record 0 of Set 6 | kiri buru
# Processing Record 1 of Set 6 | parabel
# Processing Record 2 of Set 6 | nemuro
# Processing Record 3 of Set 6 | kirakira
# Processing Record 4 of Set 6 | nara
# Processing Record 5 of Set 6 | rognan
# Processing Record 6 of Set 6 | areosa
# Processing Record 7 of Set 6 | palabuhanratu
# Processing Record 8 of Set 6 | sterling
# Processing Record 9 of Set 6 | mountain home
# Processing Record 10 of Set 6 | jiwani
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | komsomolskiy
# Processing Record 13 of Set 6 | nikolskoye
# Processing Record 14 of Set 6 | pangnirtung
# Processing Record 15 of Set 6 | bathsheba
# Processing Record 16 of Set 6 | puerto princesa
# Processing Record 17 of Set 6 | surt
# Processing Record 18 of Set 6 | bonavista
# Processing Record 19 of Set 6 | touros
# Processing Record 20 of Set 6 | kamiiso
# Processing Record 21 of Set 6 | bambous virieux
# Processing Record 22 of Set 6 | maldonado
# Processing Record 23 of Set 6 | adrar
# Processing Record 24 of Set 6 | berlevag
# Processing Record 25 of Set 6 | panjab
# Processing Record 26 of Set 6 | oktyabrskoye
# Processing Record 27 of Set 6 | beboto
# Processing Record 28 of Set 6 | klaksvik
# Processing Record 29 of Set 6 | nueva loja
# Processing Record 30 of Set 6 | damietta
# Processing Record 31 of Set 6 | sheltozero
# Processing Record 32 of Set 6 | jalu
# Processing Record 33 of Set 6 | tsihombe
# Processing Record 34 of Set 6 | sakakah
# Processing Record 35 of Set 6 | fallon
# Processing Record 36 of Set 6 | kungurtug
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | palmer
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | hirado
# Processing Record 41 of Set 6 | saint george
# Processing Record 42 of Set 6 | ryotsu
# Processing Record 43 of Set 6 | kamenskoye
# Processing Record 44 of Set 6 | hualmay
# Processing Record 45 of Set 6 | lander
# Processing Record 46 of Set 6 | sommerda
# Processing Record 47 of Set 6 | chino valley
# Processing Record 48 of Set 6 | taybad
# Processing Record 49 of Set 6 | lere
# Processing Record 0 of Set 7 | luau
# Processing Record 1 of Set 7 | armacao dos buzios
# Processing Record 2 of Set 7 | san juan
# Processing Record 3 of Set 7 | ballina
# Processing Record 4 of Set 7 | mawlamyine
# Processing Record 5 of Set 7 | svetlaya
# Processing Record 6 of Set 7 | eydhafushi
# Processing Record 7 of Set 7 | caravelas
# Processing Record 8 of Set 7 | tacoronte
# Processing Record 9 of Set 7 | talsi
# Processing Record 10 of Set 7 | fukue
# Processing Record 11 of Set 7 | srandakan
# Processing Record 12 of Set 7 | itaueira
# Processing Record 13 of Set 7 | kupang
# Processing Record 14 of Set 7 | vila do maio
# Processing Record 15 of Set 7 | mustvee
# Processing Record 16 of Set 7 | mugur-aksy
# Processing Record 17 of Set 7 | hato mayor
# Processing Record 18 of Set 7 | saint-philippe
# Processing Record 19 of Set 7 | provideniya
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | buala
# Processing Record 22 of Set 7 | dingle
# Processing Record 23 of Set 7 | usogorsk
# Processing Record 24 of Set 7 | livingston
# Processing Record 25 of Set 7 | pacific grove
# Processing Record 26 of Set 7 | vagur
# Processing Record 27 of Set 7 | porbandar
# Processing Record 28 of Set 7 | monrovia
# Processing Record 29 of Set 7 | ambanja
# Processing Record 30 of Set 7 | honiara
# Processing Record 31 of Set 7 | artyk
# Processing Record 32 of Set 7 | baluseni
# Processing Record 33 of Set 7 | puyang
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | kulhudhuffushi
# Processing Record 36 of Set 7 | svetlyy
# Processing Record 37 of Set 7 | shelburne
# Processing Record 38 of Set 7 | lagoa
# Processing Record 39 of Set 7 | lebedyn
# Processing Record 40 of Set 7 | sentyabrskiy
# Processing Record 41 of Set 7 | vanavara
# Processing Record 42 of Set 7 | corralillo
# Processing Record 43 of Set 7 | san policarpo
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | ulladulla
# Processing Record 46 of Set 7 | vila velha
# Processing Record 47 of Set 7 | lorengau
# Processing Record 48 of Set 7 | male
# Processing Record 49 of Set 7 | pokhara
# Processing Record 0 of Set 8 | kampot
# Processing Record 1 of Set 8 | huarmey
# Processing Record 2 of Set 8 | jurilovca
# Processing Record 3 of Set 8 | chauk
# Processing Record 4 of Set 8 | marawi
# Processing Record 5 of Set 8 | thayetmyo
# Processing Record 6 of Set 8 | meadow lake
# Processing Record 7 of Set 8 | were ilu
# Processing Record 8 of Set 8 | vinh
# Processing Record 9 of Set 8 | moranbah
# Processing Record 10 of Set 8 | negara
# Processing Record 11 of Set 8 | columbus
# Processing Record 12 of Set 8 | ovsyanka
# Processing Record 13 of Set 8 | narwar
# Processing Record 14 of Set 8 | bandar-e lengeh
# Processing Record 15 of Set 8 | pervomayskoye
# Processing Record 16 of Set 8 | severo-kurilsk
# Processing Record 17 of Set 8 | taltal
# Processing Record 18 of Set 8 | wabana
# Processing Record 19 of Set 8 | broken hill
# Processing Record 20 of Set 8 | tigil
# Processing Record 21 of Set 8 | muhos
# Processing Record 22 of Set 8 | russell
# Processing Record 23 of Set 8 | port hedland
# Processing Record 24 of Set 8 | lewiston
# Processing Record 25 of Set 8 | kirkwall
# Processing Record 26 of Set 8 | sidi ali
# Processing Record 27 of Set 8 | gawler
# Processing Record 28 of Set 8 | duncan
# Processing Record 29 of Set 8 | henties bay
# Processing Record 30 of Set 8 | ikalamavony
# Processing Record 31 of Set 8 | thinadhoo
# Processing Record 32 of Set 8 | hit
# Processing Record 33 of Set 8 | port-gentil
# Processing Record 34 of Set 8 | phrai bung
# Processing Record 35 of Set 8 | faanui
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | umzimvubu
# Processing Record 38 of Set 8 | kunming
# Processing Record 39 of Set 8 | morondava
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 8 | morant bay
# Processing Record 43 of Set 8 | mayo
# Processing Record 44 of Set 8 | mergui
# Processing Record 45 of Set 8 | labuhan
# Processing Record 46 of Set 8 | bage
# Processing Record 47 of Set 8 | samusu
# Processing Record 48 of Set 8 | college
# Processing Record 49 of Set 8 | beringovskiy
# Processing Record 0 of Set 9 | nur
# Processing Record 1 of Set 9 | kaitangata
# Processing Record 2 of Set 9 | port macquarie
# Processing Record 3 of Set 9 | viesca
# Processing Record 4 of Set 9 | asyut
# Processing Record 5 of Set 9 | sinop
# Processing Record 6 of Set 9 | tromso
# Processing Record 7 of Set 9 | wattegama
# Processing Record 8 of Set 9 | marzuq
# Processing Record 9 of Set 9 | kendari
# Processing Record 10 of Set 9 | jiddah
# Processing Record 11 of Set 9 | talara
# Processing Record 12 of Set 9 | montepuez
# Processing Record 13 of Set 9 | portland
# Processing Record 14 of Set 9 | yanliang
# Processing Record 15 of Set 9 | muros
# Processing Record 16 of Set 9 | nizhneyansk
# Processing Record 17 of Set 9 | birao
# Processing Record 18 of Set 9 | birjand
# Processing Record 19 of Set 9 | linxia
# Processing Record 20 of Set 9 | lanigan
# Processing Record 21 of Set 9 | healesville
# Processing Record 22 of Set 9 | bethel
# Processing Record 23 of Set 9 | gorom-gorom
# Processing Record 24 of Set 9 | chardara
# Processing Record 25 of Set 9 | dudinka
# Processing Record 26 of Set 9 | bodaybo
# Processing Record 27 of Set 9 | daru
# Processing Record 28 of Set 9 | verkhoyansk
# Processing Record 29 of Set 9 | sumbe
# Processing Record 30 of Set 9 | fereydun kenar
# Processing Record 31 of Set 9 | pionerskiy
# Processing Record 32 of Set 9 | okahandja
# Processing Record 33 of Set 9 | grand-santi
# Processing Record 34 of Set 9 | manaure
# Processing Record 35 of Set 9 | constitucion
# Processing Record 36 of Set 9 | doka
# Processing Record 37 of Set 9 | rawannawi
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | oussouye
# Processing Record 40 of Set 9 | nishihara
# Processing Record 41 of Set 9 | minna
# Processing Record 42 of Set 9 | vardo
# Processing Record 43 of Set 9 | minsk
# Processing Record 44 of Set 9 | druzhba
# Processing Record 45 of Set 9 | ostrovnoy
# Processing Record 46 of Set 9 | kasongo-lunda
# Processing Record 47 of Set 9 | richards bay
# Processing Record 48 of Set 9 | gamba
# Processing Record 49 of Set 9 | zlatoustovsk
# Processing Record 0 of Set 10 | santiago del estero
# Processing Record 1 of Set 10 | palmas bellas
# Processing Record 2 of Set 10 | byron bay
# Processing Record 3 of Set 10 | luanda
# Processing Record 4 of Set 10 | arvika
# Processing Record 5 of Set 10 | pitkyaranta
# Processing Record 6 of Set 10 | leshukonskoye
# Processing Record 7 of Set 10 | sao jose da coroa grande
# Processing Record 8 of Set 10 | portree
# Processing Record 9 of Set 10 | lesosibirsk
# Processing Record 10 of Set 10 | caxias
# Processing Record 11 of Set 10 | coahuayana
# Processing Record 12 of Set 10 | ornskoldsvik
# Processing Record 13 of Set 10 | weiz
# Processing Record 14 of Set 10 | trat
# Processing Record 15 of Set 10 | nador
# Processing Record 16 of Set 10 | chapada dos guimaraes
# Processing Record 17 of Set 10 | matara
# Processing Record 18 of Set 10 | skjervoy
# Processing Record 19 of Set 10 | karasjok
# Processing Record 20 of Set 10 | jibuti
# Processing Record 21 of Set 10 | nuuk
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | litoral del san juan
# Processing Record 24 of Set 10 | qurbus
# Processing Record 25 of Set 10 | lahat
# Processing Record 26 of Set 10 | pangai
# Processing Record 27 of Set 10 | tura
# Processing Record 28 of Set 10 | manuk mangkaw
# Processing Record 29 of Set 10 | cam ranh
# Processing Record 30 of Set 10 | camacupa
# Processing Record 31 of Set 10 | lakes entrance
# Processing Record 32 of Set 10 | shingu
# Processing Record 33 of Set 10 | presidente epitacio
# Processing Record 34 of Set 10 | villa maria
# Processing Record 35 of Set 10 | mayumba
# Processing Record 36 of Set 10 | linden
# Processing Record 37 of Set 10 | nichinan
# Processing Record 38 of Set 10 | roberto payan
# Processing Record 39 of Set 10 | omboue
# Processing Record 40 of Set 10 | palana
# Processing Record 41 of Set 10 | armidale
# Processing Record 42 of Set 10 | dergachi
# Processing Record 43 of Set 10 | noumea
# Processing Record 44 of Set 10 | bontang
# Processing Record 45 of Set 10 | juba
# Processing Record 46 of Set 10 | manoel urbano
# Processing Record 47 of Set 10 | sao gabriel da cachoeira
# Processing Record 48 of Set 10 | uyemskiy
# Processing Record 49 of Set 10 | praia da vitoria
# Processing Record 0 of Set 11 | pudozh
# Processing Record 1 of Set 11 | pravia
# Processing Record 2 of Set 11 | ayolas
# Processing Record 3 of Set 11 | sistranda
# Processing Record 4 of Set 11 | conde
# Processing Record 5 of Set 11 | saint-pierre
# Processing Record 6 of Set 11 | whitehorse
# Processing Record 7 of Set 11 | kingsville
# Processing Record 8 of Set 11 | beloha
# Processing Record 9 of Set 11 | ponta pora
# Processing Record 10 of Set 11 | rawson
# Processing Record 11 of Set 11 | bacuit
# Processing Record 12 of Set 11 | kuminskiy
# Processing Record 13 of Set 11 | mozarlandia
# Processing Record 14 of Set 11 | leh
# Processing Record 15 of Set 11 | zhanaozen
# Processing Record 16 of Set 11 | ust-ilimsk
# Processing Record 17 of Set 11 | chapleau
# Processing Record 18 of Set 11 | bargal
# Processing Record 19 of Set 11 | catamarca
# Processing Record 20 of Set 11 | tapes
# Processing Record 21 of Set 11 | cozumel
# Processing Record 22 of Set 11 | port hardy
# Processing Record 23 of Set 11 | tokzar
# Processing Record 24 of Set 11 | goldsboro
# Processing Record 25 of Set 11 | havoysund
# Processing Record 26 of Set 11 | shush
# Processing Record 27 of Set 11 | antalaha
# Processing Record 28 of Set 11 | prince rupert
# Processing Record 29 of Set 11 | maykor
# Processing Record 30 of Set 11 | tabou
# Processing Record 31 of Set 11 | olafsvik
# Processing Record 32 of Set 11 | lerwick
# Processing Record 33 of Set 11 | nisia floresta
# Processing Record 34 of Set 11 | sassandra
# Processing Record 35 of Set 11 | forquilhinha
# Processing Record 36 of Set 11 | sur
# Processing Record 37 of Set 11 | gat
# Processing Record 38 of Set 11 | lichinga
# Processing Record 39 of Set 11 | tevaitoa
# Processing Record 40 of Set 11 | skibbereen
# Processing Record 41 of Set 11 | ormond beach
# Processing Record 42 of Set 11 | duz
# Processing Record 43 of Set 11 | piranhas
# Processing Record 44 of Set 11 | wukari
# Processing Record 45 of Set 11 | naze
# Processing Record 46 of Set 11 | dicabisagan
# Processing Record 47 of Set 11 | yermolayevo
# Processing Record 48 of Set 11 | hastings
# Processing Record 49 of Set 11 | opuwo
# Processing Record 0 of Set 12 | haines junction
# Processing Record 1 of Set 12 | udachnyy
# Processing Record 2 of Set 12 | peringat
# Processing Record 3 of Set 12 | sinkat
# Processing Record 4 of Set 12 | masuda
# Processing Record 5 of Set 12 | boryslav
# Processing Record 6 of Set 12 | chandbali
# Processing Record 7 of Set 12 | sola
# Processing Record 8 of Set 12 | valparaiso
# Processing Record 9 of Set 12 | eruwa
# Processing Record 10 of Set 12 | gornyy
# Processing Record 11 of Set 12 | bulawayo
# Processing Record 12 of Set 12 | rameshki
# Processing Record 13 of Set 12 | bubaque
# Processing Record 14 of Set 12 | superior
# Processing Record 15 of Set 12 | kokopo
# Processing Record 16 of Set 12 | quthing
# Processing Record 17 of Set 12 | mailsi
# Processing Record 18 of Set 12 | mineros
# Processing Record 19 of Set 12 | rungata
# Processing Record 20 of Set 12 | ixtapa
# Processing Record 21 of Set 12 | sambava
# Processing Record 22 of Set 12 | ormara
# Processing Record 23 of Set 12 | ossora
# Processing Record 24 of Set 12 | tommot
# Processing Record 25 of Set 12 | sorvag
# Processing Record 26 of Set 12 | alta floresta
# Processing Record 27 of Set 12 | kijang
# Processing Record 28 of Set 12 | billings
# Processing Record 29 of Set 12 | acarau
# Processing Record 30 of Set 12 | matadi
# Processing Record 31 of Set 12 | malko tarnovo
# Processing Record 32 of Set 12 | oytal
# Processing Record 33 of Set 12 | banda aceh
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | faya
# Processing Record 36 of Set 12 | razole
# Processing Record 37 of Set 12 | grabovo
# Processing Record 38 of Set 12 | louisbourg
# Processing Record 39 of Set 12 | sioux lookout
# Processing Record 40 of Set 12 | umea
# Processing Record 41 of Set 12 | tumannyy
# Processing Record 42 of Set 12 | green river
# Processing Record 43 of Set 12 | diego de almagro
# Processing Record 44 of Set 12 | tenextatiloyan
# Processing Record 45 of Set 12 | vao
# Processing Record 46 of Set 12 | vestmannaeyjar

# %%
w = weather_by_city['hami']
w
# Out:
# {'coord': {'lon': 93.45, 'lat': 42.8},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'model',
#  'main': {'temp': 9.82,
#   'feels_like': 2.86,
#   'temp_min': 9.82,
#   'temp_max': 9.82,
#   'pressure': 1030,
#   'humidity': 71,
#   'sea_level': 1030,
#   'grnd_level': 912},
#  'wind': {'speed': 1.36, 'deg': 135},
#  'clouds': {'all': 99},
#  'dt': 1580075165,
#  'sys': {'country': 'CN', 'sunrise': 1580087191, 'sunset': 1580122245},
#  'timezone': 28800,
#  'id': 1529484,
#  'name': 'Kumul',
#  'cod': 200}

# %%
def get_weather(w):
    """ w is json of weather """
    temp = w['main']['temp']
    humidity = w['main']['humidity']
    cloudiness = w['clouds']['all']
    wind = w['wind']['speed']
    lat = w['coord']['lat']
    lon = w['coord']['lon']
    return temp, humidity, cloudiness, wind, lat, lon

# %%
get_weather(weather_by_city['hami'])
# Out:
# (9.82, 71, 99, 1.36, 42.8, 93.45)

# %%
weather_df = pd.DataFrame()

count = 0
for city, weath in weather_by_city.items():
    if weath['cod'] != 200:
        continue  # no data for that city
    t,h,c,w,lat,lon = get_weather(weath)
    d = {'Temp':t, 'Humidity':h, 'Clouds':c, 'Wind':w, 'Lat':lat, 'Lon':lon}
    ser = pd.Series(d, name=city)
    weather_df = weather_df.append(ser)

weather_df
# Out:
#                   Clouds  Humidity    Lat     Lon   Temp   Wind
# hobart              90.0      48.0 -42.88  147.33  57.18  11.41
# iberia              75.0      77.0  29.95  -91.75  56.26  10.29
# punta arenas        40.0      44.0 -53.15  -70.92  57.11  23.04
# isangel             42.0      83.0 -19.55  169.27  78.71  13.44
# chokurdakh         100.0      97.0  70.63  147.92 -23.10   5.64
# ...                  ...       ...    ...     ...    ...    ...
# umea               100.0      73.0  63.83   20.26  24.40   8.05
# green river         75.0      69.0  41.53 -109.47  38.12   3.58
# diego de almagro    40.0      37.0 -26.37  -70.05  82.98  16.98
# vao                 99.0      83.0 -22.67  167.48  77.68  12.97
# vestmannaeyjar     100.0      59.0  63.44  -20.27  38.46  21.45
#
# [560 rows x 6 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv("weather.csv")

# %%
weather_df
# Out:
#                   Clouds  Humidity    Lat     Lon   Temp   Wind
# hobart              90.0      48.0 -42.88  147.33  57.18  11.41
# iberia              75.0      77.0  29.95  -91.75  56.26  10.29
# punta arenas        40.0      44.0 -53.15  -70.92  57.11  23.04
# isangel             42.0      83.0 -19.55  169.27  78.71  13.44
# chokurdakh         100.0      97.0  70.63  147.92 -23.10   5.64
# ...                  ...       ...    ...     ...    ...    ...
# umea               100.0      73.0  63.83   20.26  24.40   8.05
# green river         75.0      69.0  41.53 -109.47  38.12   3.58
# diego de almagro    40.0      37.0 -26.37  -70.05  82.98  16.98
# vao                 99.0      83.0 -22.67  167.48  77.68  12.97
# vestmannaeyjar     100.0      59.0  63.44  -20.27  38.46  21.45
#
# [560 rows x 6 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# import seaborn as sns
# sns.replot

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
